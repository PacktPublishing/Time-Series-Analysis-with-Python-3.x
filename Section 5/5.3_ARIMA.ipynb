# %% [markdown]
# # ARIMA Model for Forecasting

# %% [markdown]
# ARIMA (AutoRegressive Integrated Moving Average) is a model that focuses on a set of time structures in data. It is used for both analysis and forecasting in time series data.  The three components are autoregression, integrated, and moving average.  For autoregression, it is simply a model between a target variable's data and its lagged values.  For integrated, it is when you use .diff() to difference the data in order to improve stationarity. You can use second and third order differencings, which go beyond the first difference.  For moving average, just as previously discussed, it focuses on data and residual error from a moving average model applied to lagged observations.

# %%
import pandas as pd
from pandas import read_csv
from matplotlib import pyplot

# %% [markdown]
# ## Example 1: Vacation dataset

# %%
vacat= pd.read_csv('~/Desktop/section_5/df_vacation.csv', index_col=0, parse_dates=True)
vacat.head()
# Out:
#             Num_Search_Vacation
# Month
# 2004-01-01                   94
# 2004-02-01                   89
# 2004-03-01                   86
# 2004-04-01                   79
# 2004-05-01                   89

# %%
# ARIMA model

from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot 

# ARIMA.fit(start_params=None, trend='c', method='css-mle', transparams=True, solver='lbfgs', maxiter=500, 
#          full_output=1, disp=5, callback=None, start_ar_lags=None, **kwargs)[source]
# Fits ARIMA(p,d,q) model by exact maximum likelihood via Kalman filter.


# p: The number of lag observations included in the model, also called the lag order.
# d: The number of times that the raw observations are differenced, also called the degree of differencing.
# q: The size of the moving average window, also called the order of moving average.

model = ARIMA(vacat,order=(1,1,1)) 
# fit model
model_fit = model.fit()  
print(model_fit.summary())
# Out:
# /Users/karenyang/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/karenyang/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                                ARIMA Model Results
# =================================================================================
# Dep. Variable:     D.Num_Search_Vacation   No. Observations:                  189
# Model:                    ARIMA(1, 1, 1)   Log Likelihood                -683.838
# Method:                          css-mle   S.D. of innovations              8.931
# Date:                   Sun, 01 Dec 2019   AIC                           1375.675
# Time:                           19:44:46   BIC                           1388.642
# Sample:                       02-01-2004   HQIC                          1380.928
#                             - 10-01-2019
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -0.1893      0.034     -5.504      0.000      -0.257      -0.122
# ar.L1.D.Num_Search_Vacation     0.6666      0.055     12.013      0.000       0.558       0.775
# ma.L1.D.Num_Search_Vacation    -1.0000      0.023    -44.422      0.000      -1.044      -0.956
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.5001           +0.0000j            1.5001            0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# The number of observations is 189.  The standard deviation is 8.931.  The lag variables for both AR(1) and MA(1) are both statistically significant, based off of the p-values, which are 0.00.

# %%
# line plot of residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()

# %%
# kernel density plot of residual errors
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
#                 0
# count  189.000000
# mean    -0.611513
# std      9.039776
# min    -21.836469
# 25%     -6.429926
# 50%     -0.839614
# 75%      4.209086
# max     29.140171

# %% [markdown]
# The mean is close to zero and the standard deviation is 9.039.

# %%
# Forecast with ARIMA model
# Import the ARIMA module from statsmodels
from statsmodels.tsa.arima_model import ARIMA
import matplotlib.pyplot as plt

mod = ARIMA(vacat,order=(1,1, 1))
res = mod.fit()

# Plot the original series and the forecasted series
#res.plot_predict()
res.plot_predict(start='2015-01-01',end='2025-01-01')
plt.legend(fontsize=8)
plt.show();
# Out:
# /Users/karenyang/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/karenyang/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %% [markdown]
# The blue color, which is the predicted values, come very close to the actual values.  We can see the forecast at 2020.

# %% [markdown]
# ## Example 2:  Furniture Dataset

# %%
furn= pd.read_csv('~/Desktop/section_5/df_furniture.csv', index_col=0, parse_dates=True)
furn.head()
# Out:
#             furniture_price_adjusted
# Month
# 1992-01-01               2073.432724
# 1992-02-01               2114.485812
# 1992-03-01               2260.570891
# 1992-04-01               2255.103236
# 1992-05-01               2331.414618

# %%
# ARIMA Model
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

# ARIMA.fit(start_params=None, trend='c', method='css-mle', transparams=True, solver='lbfgs', maxiter=500, 
#          full_output=1, disp=5, callback=None, start_ar_lags=None, **kwargs)[source]
# Fits ARIMA(p,d,q) model by exact maximum likelihood via Kalman filter.


# p: The number of lag observations included in the model, also called the lag order.
# d: The number of times that the raw observations are differenced, also called the degree of differencing.
# q: The size of the moving average window, also called the order of moving average.


model = ARIMA(furn,order=(1,1,1)) 
# fit model
model_fit = model.fit() 
print(model_fit.summary())
# Out:
# /Users/karenyang/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/karenyang/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                                  ARIMA Model Results
# ======================================================================================
# Dep. Variable:     D.furniture_price_adjusted   No. Observations:                  330
# Model:                         ARIMA(1, 1, 1)   Log Likelihood               -2542.842
# Method:                               css-mle   S.D. of innovations            536.570
# Date:                        Sun, 01 Dec 2019   AIC                           5093.683
# Time:                                19:47:56   BIC                           5108.880
# Sample:                            02-01-1992   HQIC                          5099.745
#                                  - 07-01-2019
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                               22.6854      5.756      3.941      0.000      11.404      33.967
# ar.L1.D.furniture_price_adjusted     0.1604      0.063      2.565      0.011       0.038       0.283
# ma.L1.D.furniture_price_adjusted    -0.8389      0.028    -30.284      0.000      -0.893      -0.785
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            6.2339           +0.0000j            6.2339            0.0000
# MA.1            1.1920           +0.0000j            1.1920            0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# Both the AR(1) and the MA(1) lagged variables are statistically significant with low p-value scores.

# %%
# line plot of residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()

# %%
# kernel density plot of residual errors
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
#                  0
# count   330.000000
# mean      0.983107
# std     537.403502
# min   -1657.540721
# 25%    -274.880580
# 50%      44.350695
# 75%     269.821545
# max    1618.078490

# %% [markdown]
# Notice the mean and standard deviation as the distribution of the residuals are shown. The mean is nearly zero in the residuals, suggesting no bias in prediction.

# %%
# Forecast with ARIMA model
# Import the ARIMA module from statsmodels
from statsmodels.tsa.arima_model import ARIMA
import matplotlib.pyplot as plt

mod = ARIMA(furn,order=(1,1, 1))
res = mod.fit()

# Plot the original series and the forecasted series
#res.plot_predict()
res.plot_predict(start='2015-01-01',end='2025-01-01')
plt.legend(fontsize=8)
plt.show();
# Out:
# /Users/karenyang/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/karenyang/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %% [markdown]
# You can see how far off the forecasted values are against the actual values as well as the predictions at 2020 and beyond.

# %% [markdown]
# ## Example 3:  Bank of America

# %%
bac = pd.read_csv('~/Desktop/section_5/df_bankofamerica.csv', index_col=0, parse_dates=True)
bac=bac.resample(rule='W').last()  # rule is weekly and last day of week
bac.head()
# Out:
#             Adj Close Price
# Date
# 1990-01-07         1.652200
# 1990-01-14         1.569591
# 1990-01-21         1.624664
# 1990-01-28         1.578769
# 1990-02-04         1.574180

# %%
bac.tail()
# Out:
#             Adj Close Price
# Date
# 2019-09-22        29.590000
# 2019-09-29        29.350000
# 2019-10-06        28.370001
# 2019-10-13        28.910000
# 2019-10-20        30.170000

# %%
# ARIMA Model
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

# ARIMA.fit(start_params=None, trend='c', method='css-mle', transparams=True, solver='lbfgs', maxiter=500, 
#          full_output=1, disp=5, callback=None, start_ar_lags=None, **kwargs)[source]
# Fits ARIMA(p,d,q) model by exact maximum likelihood via Kalman filter.


# p: The number of lag observations included in the model, also called the lag order.
#d: The number of times that the raw observations are differenced, also called the degree of differencing.
# q: The size of the moving average window, also called the order of moving average.


model = ARIMA(bac,order=(1,1,1)) 
# fit model
model_fit = model.fit()  
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:      D.Adj Close Price   No. Observations:                 1554
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -1921.283
# Method:                       css-mle   S.D. of innovations              0.833
# Date:                Sun, 01 Dec 2019   AIC                           3850.567
# Time:                        19:50:04   BIC                           3871.961
# Sample:                    01-14-1990   HQIC                          3858.523
#                          - 10-20-2019
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.0184      0.021      0.893      0.372      -0.022       0.059
# ar.L1.D.Adj Close Price    -0.8721      0.047    -18.477      0.000      -0.965      -0.780
# ma.L1.D.Adj Close Price     0.8217      0.054     15.237      0.000       0.716       0.927
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.1466           +0.0000j            1.1466            0.5000
# MA.1           -1.2170           +0.0000j            1.2170            0.5000
# -----------------------------------------------------------------------------

# %% [markdown]
# Both AR(1) and MA(1) lagged variables are statistically significant.  The p-values are 0.00.

# %%
# line plot of residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()

# %%
# kernel density plot of residual errors
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
#                  0
# count  1554.000000
# mean     -0.000006
# std       0.833368
# min     -11.988227
# 25%      -0.293216
# 50%       0.007842
# 75%       0.303397
# max       5.232681

# %%
# Forecast with ARIMA model
# Import the ARIMA module from statsmodels
from statsmodels.tsa.arima_model import ARIMA
import matplotlib.pyplot as plt

mod = ARIMA(bac,order=(1,1, 1))
res = mod.fit()

# Plot the original series and the forecasted series
#res.plot_predict()
res.plot_predict(start='2015',end='2025')
plt.legend(fontsize=8)
plt.show();

# %% [markdown]
# Predicted values are very closely aligned to actual values.  Forecast is shown.

# %% [markdown]
# ## Example 4:  J. P. Morgan

# %%
jpm = pd.read_csv('~/Desktop/section_5/df_jpmorgan.csv', index_col=0, parse_dates=True)
jpm = jpm.resample(rule='W').last()
jpm.head()
# Out:
#             Adj Close Price
# Date
# 1990-01-07         3.760463
# 1990-01-14         3.549875
# 1990-01-21         3.474666
# 1990-01-28         3.188872
# 1990-02-04         3.143746

# %%
# ARIMA Model
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

# ARIMA.fit(start_params=None, trend='c', method='css-mle', transparams=True, solver='lbfgs', maxiter=500, 
#          full_output=1, disp=5, callback=None, start_ar_lags=None, **kwargs)[source]
# Fits ARIMA(p,d,q) model by exact maximum likelihood via Kalman filter.


# p: The number of lag observations included in the model, also called the lag order.
# d: The number of times that the raw observations are differenced, also called the degree of differencing.
# q: The size of the moving average window, also called the order of moving average.


model = ARIMA(jpm,order=(1,1,1)) 
# fit model
model_fit = model.fit()  
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:      D.Adj Close Price   No. Observations:                 1554
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -2801.766
# Method:                       css-mle   S.D. of innovations              1.468
# Date:                Sun, 01 Dec 2019   AIC                           5611.532
# Time:                        19:51:44   BIC                           5632.926
# Sample:                    01-14-1990   HQIC                          5619.488
#                          - 10-20-2019
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.0746      0.036      2.082      0.037       0.004       0.145
# ar.L1.D.Adj Close Price    -0.7829      0.076    -10.294      0.000      -0.932      -0.634
# ma.L1.D.Adj Close Price     0.7150      0.085      8.449      0.000       0.549       0.881
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.2774           +0.0000j            1.2774            0.5000
# MA.1           -1.3986           +0.0000j            1.3986            0.5000
# -----------------------------------------------------------------------------

# %% [markdown]
# Again, we see statistically significant variables for AR(1) and MA(1) lagged variables. P-values are 0.00.

# %%
# line plot of residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()

# %%
# kernel density plot of residual errors
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
#                  0
# count  1554.000000
# mean     -0.000011
# std       1.468606
# min      -8.904250
# 25%      -0.553267
# 50%      -0.031181
# 75%       0.518402
# max       8.131998

# %%
# Forecast with ARIMA model
# Import the ARIMA module from statsmodels
from statsmodels.tsa.arima_model import ARIMA
import matplotlib.pyplot as plt

mod = ARIMA(jpm,order=(1,1, 1))
res = mod.fit()

# Plot the original series and the forecasted series
#res.plot_predict()
res.plot_predict(start='2015',end='2025')
plt.legend(fontsize=8)
plt.show();

# %% [markdown]
# Plot shows strong alignment between predicted and actual values. Forecast is shown.

# %% [markdown]
# ## Example 5: Average Temperature of St. Louis

# %%
temp = pd.read_csv('~/Desktop/section_5/df_temp.csv', index_col=0, parse_dates=True)
temp.head()
# Out:
#             Value
# Date
# 1938-04-01   56.5
# 1938-05-01   64.7
# 1938-06-01   73.5
# 1938-07-01   80.4
# 1938-08-01   81.3

# %%
# ARIMA Model
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

# ARIMA.fit(start_params=None, trend='c', method='css-mle', transparams=True, solver='lbfgs', maxiter=500, 
#          full_output=1, disp=5, callback=None, start_ar_lags=None, **kwargs)[source]
# Fits ARIMA(p,d,q) model by exact maximum likelihood via Kalman filter.


# p: The number of lag observations included in the model, also called the lag order.
# d: The number of times that the raw observations are differenced, also called the degree of differencing.
# q: The size of the moving average window, also called the order of moving average.



model = ARIMA(temp,order=(1,0,1)) 
# fit model
model_fit = model.fit()  
print(model_fit.summary())
# Out:
# /Users/karenyang/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  Value   No. Observations:                  970
# Model:                     ARMA(1, 1)   Log Likelihood               -3433.149
# Method:                       css-mle   S.D. of innovations              8.327
# Date:                Sun, 01 Dec 2019   AIC                           6874.299
# Time:                        19:53:24   BIC                           6893.808
# Sample:                    04-01-1938   HQIC                          6881.724
#                          - 01-01-2019
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          56.3346      1.584     35.576      0.000      53.231      59.438
# ar.L1.Value     0.7533      0.022     33.549      0.000       0.709       0.797
# ma.L1.Value     0.4662      0.024     19.492      0.000       0.419       0.513
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3275           +0.0000j            1.3275            0.0000
# MA.1           -2.1448           +0.0000j            2.1448            0.5000
# -----------------------------------------------------------------------------

# %% [markdown]
# Both AR(1) and MA(1) variables are statistically significant. P-values are 0.00.

# %%
# line plot of residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()

# %%
# kernel density plot of residual errors
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
#                 0
# count  970.000000
# mean     0.001836
# std      8.332191
# min    -25.851834
# 25%     -5.864227
# 50%      0.434147
# 75%      5.837974
# max     24.523173

# %%
# Forecast with ARIMA model
# Import the ARIMA module from statsmodels
from statsmodels.tsa.arima_model import ARIMA
import matplotlib.pyplot as plt

mod = ARIMA(temp,order=(1, 0, 1))
res = mod.fit()

# Plot the original series and the forecasted series
#res.plot_predict()
res.plot_predict(start='2015',end='2025')
plt.legend(fontsize=8)
plt.show();
# Out:
# /Users/karenyang/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %% [markdown]
# Plot aligns very well with slight offsets at peaks and dips. Forecast is shown.

# %%
# end
